# %% [markdown]
# <a href="https://colab.research.google.com/github/Mastersuek/Skillfactory/blob/master/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-04-09T04:40:30.742607Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 3.09}
# {"timestamp": "2026-04-09T04:40:33.328112Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 9.58}
# {"timestamp": "2026-04-09T04:40:33.827165Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 32.58}
# {"timestamp": "2026-04-09T04:40:34.287644Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 21.64}
# {"timestamp": "2026-04-09T04:40:35.398058Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 7.64}
# {"timestamp": "2026-04-09T04:40:45.390070Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-04-09T04:41:42.340809Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 7.0}
# {"timestamp": "2026-04-09T04:41:44.338609Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.65}
# {"timestamp": "2026-04-09T04:41:44.801751Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.82}
# {"timestamp": "2026-04-09T04:41:45.290163Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.33}
# {"timestamp": "2026-04-09T04:41:46.215441Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.35}
# {"timestamp": "2026-04-09T04:42:35.442169Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 76.99}
# {"timestamp": "2026-04-09T04:42:36.030700Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 157.72}
# {"timestamp": "2026-04-09T04:42:36.539818Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.36}
# {"timestamp": "2026-04-09T04:42:36.967126Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.26}
# {"timestamp": "2026-04-09T04:42:38.334854Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.34}
# {"timestamp": "2026-04-09T04:42:38.749531Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.24}
# {"timestamp": "2026-04-09T04:44:05.942895Z", "level": "info", "event": "Getting model config for: unsloth/Qwen3.5-9B"}
# {"timestamp": "2026-04-09T04:44:05.952444Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-04-09T04:44:05.961669Z", "level": "info", "event": "Model 'unsloth/Qwen3.5-9B' needs transformers 5.x -- checking vision via subprocess"}
# {"timestamp": "2026-04-09T04:44:24.412693Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/Qwen3.5-9B': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-04-09T04:44:25.880507Z", "level": "info", "event": "Model 'unsloth/Qwen3.5-9B' needs transformers 5.x -- checking vision via subprocess"}
# {"timestamp": "2026-04-09T04:44:34.221144Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/Qwen3.5-9B': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-04-09T04:44:37.787214Z", "level": "info", "event": "Model config result for unsloth/Qwen3.5-9B: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-04-09T04:44:38.033305Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Qwen3.5-9B", "status_code": 200, "process_time_ms": 32093.79}
# {"timestamp": "2026-04-09T04:44:38.040306Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/huggingface.svg", "status_code": 200, "process_time_ms": 5.09}
# ={"timestamp": "2026-04-09T04:46:19.080142Z", "level": "info", "event": "Checking format for dataset: unsloth/llava-instruct-mix-vsft-mini"}
# {"timestamp": "2026-04-09T04:46:19.343085Z", "level": "info", "event": "Tier 1: loading single file data/test-00000-of-00001.parquet"}
# README.md:   0%|          | 0.00/728 [00:00<?, ?B/s]
# {"timestamp": "2026-04-09T04:46:24.914421Z", "level": "info", "event": "Format check result: requires_mapping=False, format=vlm_messages_llava, is_image=False"}
# {"timestamp": "2026-04-09T04:46:24.978294Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 5903.14}
# {"timestamp": "2026-04-09T04:46:33.925082Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/system/hardware", "status_code": 200, "process_time_ms": 7.08}
# {"timestamp": "2026-04-09T04:46:37.199175Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.41}
# {"timestamp": "2026-04-09T04:46:37.654387Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.41}
# {"timestamp": "2026-04-09T04:46:40.008812Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 6.22}
# {"timestamp": "2026-04-09T04:46:40.014342Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-04-09T04:46:40.527530Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.92}
# ==========={"timestamp": "2026-04-09T05:43:28.104144Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.55}
# ==

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
